# %% [markdown]
# # LinkedList

# %% [markdown]
# - Linear data structure.
# - used to store data in non-contiguous memory locations.

# %% [markdown]
# ### TimeComplexity of write
# - O(1)

# %%
class Node:
    def __init__(self,value):
        self.data = value
        self.next = None

# %%
a = Node(1)
b = Node(2)
a.next = b
b.next = None
print(a.data)
print(a.next.data)
# Out:
# 1
# 2

# %%
print(a.next)
print(b.next)
# Out:
# ...
# None

# %%
print(id(a))
print(id(b))
# Out:
# 4573532512
# 4572831408

# %%
class Node:
    def __init__(self,value):
        self.data = value
        self.next = None

# %%
class LinkedList:
    def __init__(self):
        # Empty Linked List
        self.head = None
        self.n = 0 # noumeber of nodes in linked list

    def __len__(self):
        return self.n   
    def insert_head(self,value):
        #new node to be inserted
        new_node = Node(value)
        #point new node to head
        new_node.next = self.head
        #update head to new node
        self.head = new_node 
        # increment the number of nodes
        self.n = self.n + 1

    def traverse(self):
        curr = self.head
        result = ''
        while curr != None:
            result += str(curr.data) + ' -> '
            curr = curr.next
        return result[:-4]  # remove the last arrow

    def append(self, value):
        new_node = Node(value)
        if self.head == None:
            self.head = new_node
            self.n = self.n +1
            return
        curr = self.head
        while curr.next != None:
            curr = curr.next
        curr.next = new_node 
        self.n = self.n + 1

    def insert_after(self,after, value):
        new_node = Node(value)
        curr = self.head
        while curr != None:
            if curr.data == after:
                break
            curr = curr.next
        if curr != None:
            new_node.next = curr.next
            curr.next = new_node
            self.n = self.n + 1
        else:
            return 'Item not found'     

    def clear(self):
        self.head = None
        self.n = 0 

    def delete_head(self):
        if self.head == None:
            return 'LinkedList is empty'
        self.head = self.head.next
        self.n = self.n -1
        if self.head == None:
            return 'LinkedList is empty'

# %%
L = LinkedList()

# %%
len(L)
# Out:
# 0

# %%
L.append(-10)
print(L.traverse())
# Out:
# -10

# %% [markdown]
# #### Four operation performed in LinkedList
# - Insert
# - Traverse
# - Delete
# - Search

# %%
L = LinkedList()

# %%
L.insert_head(10)
L.insert_head(20)
L.insert_head(30)
L.insert_head(40)

# %%
print(L.traverse())
# Out:
# 40 -> 30 -> 20 -> 10

# %%
L.append(0)
print(L.traverse())
# Out:
# 40 -> 30 -> 20 -> 10 -> 0

# %%
print(L.insert_after(20, 25))
print(L.traverse())
# Out:
# None
# 40 -> 30 -> 20 -> 25 -> 10 -> 0

# %%
print(L.insert_after(10000, 25))
# Out:
# Item not found

# %%
print(L.clear())
print(L.traverse())
# Out:
# None

# %%
L = LinkedList()

L.insert_head(10)
L.insert_head(20)
L.insert_head(30)
L.insert_head(40)

print(L.traverse())
print(len(L))
# Out:
# 40 -> 30 -> 20 -> 10
# 4

# %%
L.delete_head()

print(L.traverse())
print(len(L))
# Out:
# 30 -> 20 -> 10
# 3

# %%
L.delete_head()

print(L.traverse())
print(len(L))
# Out:
# 20 -> 10
# 2

# %%
L.delete_head()

print(L.traverse())
print(len(L))
# Out:
# 10
# 1

# %%
L.delete_head()

print(L.traverse())
print(len(L))
# Out:
# 0

# %%
L.delete_head()

print(L.traverse())
print(len(L))
# Out:
# 0
